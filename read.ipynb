# %%
from PIL import Image, ImageOps

# %% [markdown]
# Pillow docs: https://pillow.readthedocs.io/

# %%
frame = Image.open('2021-03-27_965657358/001470.png')
frame
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x720 at 0x7F12A4F1C730>

# %%
frame2 = Image.open('2021-03-27_965657358/001380.png')
frame2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x720 at 0x7F12A4649550>

# %%
frame.size
# Out:
# (1280, 720)

# %%
# Read player names from bottom left

# %%
ImageOps.scale(frame.crop((42, 486, 193, 500)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=604x56 at 0x7F12A4100670>

# %%
ImageOps.scale(frame.crop((88, 518, 194, 534)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=424x64 at 0x7F12A4100430>

# %%
ImageOps.scale(frame.crop((88, 562, 194, 578)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=424x64 at 0x7F12A4100BE0>

# %%
ImageOps.scale(frame.crop((113, 640, 267, 660)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=616x80 at 0x7F12A4649280>

# %%
# Read weapons from bottom right

# %%
ImageOps.scale(frame.crop((1036, 686, 1107, 705)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=284x76 at 0x7F12A4100550>

# %%
ImageOps.scale(frame.crop((1140, 686, 1210, 705)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=280x76 at 0x7F12A4100DC0>

# %%
# Read character portraits from bottom left

# %%
ImageOps.scale(frame.crop((50, 516, 84, 548)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=136x128 at 0x7F12A4100F70>

# %%
ImageOps.scale(frame.crop((50, 560, 84, 592)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=136x128 at 0x7F12A4100DF0>

# %%
ImageOps.scale(frame.crop((61, 636, 117, 686)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=224x200 at 0x7F12A4100C70>

# %%
# Read round number and clock from top left

# %%
ImageOps.scale(frame.crop((34, 224, 192, 240)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=632x64 at 0x7F12A4096C40>

# %%
ImageOps.scale(frame2.crop((70, 210, 170, 230)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=400x80 at 0x7F12A4096B50>

# %%
ImageOps.scale(frame.crop((1090, 36, 1120, 52)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=120x64 at 0x7F12A40F7F10>

# %%
import pytesseract

# %%
print(pytesseract.image_to_string(frame.crop((113, 640, 267, 660))))
# Out:
# CLGImMadress4# OF

# %%
print(pytesseract.image_to_data(frame.crop((113, 640, 267, 660))))
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	154	20	-1
# 2	1	1	0	0	0	6	1	145	19	-1
# 3	1	1	1	0	0	6	1	145	19	-1
# 4	1	1	1	1	0	6	1	145	19	-1
# 5	1	1	1	1	1	6	6	91	10	35	CLGImMadress4#
# 5	1	1	1	1	2	112	0	11	20	8	OF
