# %%
from PIL import Image, ImageOps

# %%
# Get 1-2 images per second from video

# %%
frame = Image.open('screen.png')
frame
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1080 at 0x7EFC34CD4610>

# %%
frame.size
# Out:
# (1920, 1080)

# %%
# Read player names from bottom left

# %%
ImageOps.scale(frame.crop((65, 730, 290, 750)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=900x80 at 0x7EFC34CD41F0>

# %%
ImageOps.scale(frame.crop((133, 778, 290, 800)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=628x88 at 0x7EFC3441C5E0>

# %%
ImageOps.scale(frame.crop((133, 844, 290, 866)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=628x88 at 0x7EFC3441C280>

# %%
ImageOps.scale(frame.crop((170, 960, 400, 990)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=920x120 at 0x7EFC3441CFD0>

# %%
# Read weapons from bottom right

# %%
ImageOps.scale(frame.crop((1555, 1030, 1660, 1057)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=420x108 at 0x7EFC3441C7F0>

# %%
ImageOps.scale(frame.crop((1695, 1030, 1815, 1057)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=480x108 at 0x7EFC34CD4A90>

# %%
# Read character portraits from bottom left

# %%
ImageOps.scale(frame.crop((75, 775, 125, 822)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=200x188 at 0x7EFC343C90D0>

# %%
ImageOps.scale(frame.crop((75, 841, 125, 888)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=200x188 at 0x7EFC343C95E0>

# %%
ImageOps.scale(frame.crop((92, 955, 175, 1028)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=332x292 at 0x7EFC34CD44C0>

# %%
# Read round number and clock from top left

# %%
ImageOps.scale(frame.crop((100, 310, 260, 350)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=640x160 at 0x7EFC3440A1F0>

# %%
ImageOps.scale(frame.crop((1635, 54, 1680, 77)), 4.0, Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=180x92 at 0x7EFC343C9790>
